# %%
1.
from sklearn.datasets import load_iris
import pandas as pd
data=load_iris()
x=pd.DataFrame(data.data,columns=data.feature_names)
x
y=data.target

# %%
from sklearn.neighbors import KNeighborsClassifier,KNeighborsRegressor
from sklearn.metrics import r2_score, accuracy_score, confusion_matrix, classification_report,mean_absolute_error
from sklearn.model_selection import train_test_split,GridSearchCV
x_train, x_test, y_train, y_test=train_test_split(x,y)
knnc=KNeighborsClassifier()
knnc.fit(x_train,y_train)
y_pred=knnc.predict(x_test)
print(confusion_matrix(y_test, y_pred),
classification_report(y_test, y_pred))
# Out:
# [[17  0  0]
#  [ 0  8  0]
#  [ 0  1 12]]               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        17
#            1       0.89      1.00      0.94         8
#            2       1.00      0.92      0.96        13
#
#     accuracy                           0.97        38
#    macro avg       0.96      0.97      0.97        38
# weighted avg       0.98      0.97      0.97        38

# %%
2.
knnr=KNeighborsRegressor()
knnr.fit(x_train,y_train)
y_pred=knnr.predict(x_test)
print(r2_score(y_test, y_pred),
mean_absolute_error(y_test, y_pred))
# Out:
# 0.9486120996441281 0.0631578947368421

# %%
3.
gscv=GridSearchCV(KNeighborsClassifier(),param_grid={"n_neighbors":[1,2,3,4,5,6,7]} ,cv=5,n_jobs=-1)
gscv.fit(x_train, y_train)
gscv.best_params_
# Out:
# {'n_neighbors': 1}

# %%
4.
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x_train=ss.fit_transform(x_train)
x_test=ss.transform(x_test)

knnr=KNeighborsRegressor()
knnr.fit(x_train, y_train)
y_pred=knnr.predict(x_test)
print(r2_score(y_test, y_pred),
mean_absolute_error(y_test, y_pred))
#we cant use scaler in knn reg
# Out:
# 0.929679715302491 0.09473684210526316

# %%
5.
x_train, x_test, y_train, y_test=train_test_split(x,y)
knnc=KNeighborsClassifier(weights="distance")
knnc.fit(x_train,y_train)
y_pred=knnc.predict(x_test)
print(confusion_matrix(y_test, y_pred),
classification_report(y_test, y_pred))
#performace is increse by distnace weigth
# Out:
# [[14  0  0]
#  [ 0  8  1]
#  [ 0  0 15]]               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      0.89      0.94         9
#            2       0.94      1.00      0.97        15
#
#     accuracy                           0.97        38
#    macro avg       0.98      0.96      0.97        38
# weighted avg       0.98      0.97      0.97        38

# %%
6.
def stands(train,test):
    ss=StandardScaler()
    x_train=ss.fit_transform(train)
    x_test=ss.transform(test)
    return x_train, x_test

# %%
stands(x_train, x_test)
# Out:
# (array([[-0.42937129, -1.43725064, -0.02687609, -0.22771216],
#         [-0.9188327 ,  1.44914513, -1.30038916, -1.05041417],
#         [ 0.6719169 ,  0.33899291,  0.43621958,  0.45787284],
#         [ 0.79428225, -0.10506798,  1.18875003,  1.41769185],
#         [ 0.79428225, -0.10506798,  1.01508916,  0.86922385],
#         [ 1.65083973, -0.10506798,  1.18875003,  0.59498984],
#         [-0.18464058, -0.54912887,  0.43621958,  0.18363884],
#         [ 0.54955155, -0.54912887,  0.78354133,  0.45787284],
#         [-0.18464058, -0.32709842,  0.2625587 ,  0.18363884],
#         [-0.55173664,  1.89320602, -1.41616308, -1.05041417],
#         [ 0.42718619, -0.54912887,  0.60988045,  0.86922385],
#         [ 0.42718619, -1.88131153,  0.43621958,  0.45787284],
#         [ 0.6719169 , -0.77115931,  0.89931524,  1.00634085],
#         [ 2.2626665 ,  1.67117558,  1.70973265,  1.41769185],
#         [-0.9188327 ,  0.7830538 , -1.30038916, -1.32464817],
# ...

# %%
7.
from math import sqrt
def ED(x1,y1,x2,y2):
    d=sqrt((x2-x1)**2 +(y2-y1)**2)
    return d

# %%
ED(1,0,2,2)
# Out:
# 2.23606797749979

# %%
8.
def MD(x1,y1,x2,y2):
    d=abs((x2-x1)) +abs((y2-y1))
    return d

# %%
MD(1,0,2,2)
# Out:
# 3
