# %% [markdown]
# 1.Probability density function is a function which used to find probabliry of an event

# %% [raw]
# 2.
# probability distubustion function ,
# probablility mass function
# cumelative distubustion function

# %%
3.
from scipy.stats import norm
import seaborn as sms

mean=20
std=10
x=[]
y=[]
for i in  range(100):
    x.append(i)
    probability_pdf = norm.pdf(i, loc=mean, scale=std)
    y.append(probability_pdf)
sms.lineplot(y)

print(probability_pdf)
# norm.pdf funstion used to get normal distubutiomn
# Out:
# 1.1187956214351817e-15

# %% [markdown]
# 4.Binomial distribution
# it is a probablity mass function
# p=no of probabality of win
# q=p-1
# *tossing a coin
# *rolling a deis on getting an even or odd number

# %%
5.

from scipy.stats import binom
import matplotlib.pyplot as plt
# setting the values
# of n and p
n = 1000
p = .4
# defining list of r values
r_values = list(range(n + 1))
# list of pmf values
dist = [binom.pmf(r, n, p) for r in r_values ]
# plotting the graph 
plt.bar(r_values, dist)
plt.show()

# %%
6.
from scipy.stats import poisson
import matplotlib.pyplot as plt

#generate Poisson distribution with sample size 10000
x = poisson.rvs(mu=3, size=10000)

#create plot of Poisson distribution
plt.hist(x, density=True, edgecolor='black')
# Out:
# (array([1.52615385e-01, 1.72692308e-01, 1.81076923e-01, 2.00538462e-01,
#         3.66153846e-02, 1.74615385e-02, 7.53846154e-03, 4.61538462e-04,
#         1.53846154e-04, 7.69230769e-05]),
#  array([ 0. ,  1.3,  2.6,  3.9,  5.2,  6.5,  7.8,  9.1, 10.4, 11.7, 13. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# 7.How Binomial distribution different from Poisson distribution?
# binomial distribution  bolleam value of winning in n bernoulli distubtion
# Poisson distribution is value of probablilty winner for every re

# %%
8.
from scipy.stats import poisson
import matplotlib.pyplot as plt

#generate Poisson distribution with sample size 10000
x = poisson.rvs(mu=5, size=10000)
print(x.mean())
print(x.std())
# Out:
# 5.0003
# 2.210271456179082

# %% [markdown]
# 9.
# binomial distubtion
# mean=n*p, where p is prorblity of wining rate
# var=n*p*q  where q=1-p
# postion distubtion
# mean=var=t*p where t = time, p=probolity of win at every interval of time

# %% [markdown]
# 10.
#
# 4th standent devation - 3rd standent devation
