# %%
import pandas as pd
import tensorflow as tf


print(tf.__version__)
print(keras.__version__)


df=pd.read_csv("wine.csv")
df.head()

df.isnull().sum()

df.dtypes

df['quality']=df['quality'].replace({"good":1,"bad":0})


x=df.drop("quality" ,axis=1)
x.head()

from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x=pd.DataFrame(ss.fit_transform(x),columns=ss.get_feature_names_out())
x.head()
# Out:
# 2.13.0
# 2.13.1
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0      -0.528360          0.961877    -1.391472       -0.453218  -0.243707
# 1      -0.298547          1.967442    -1.391472        0.043416   0.223875
# 2      -0.298547          1.297065    -1.186070       -0.169427   0.096353
# 3       1.654856         -1.384443     1.484154       -0.453218  -0.264960
# 4      -0.528360          0.961877    -1.391472       -0.453218  -0.243707
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0            -0.466193             -0.379133  0.558274  1.288643  -0.579207
# 1             0.872638              0.624363  0.028261 -0.719933   0.128950
# 2            -0.083669              0.229047  0.134264 -0.331177  -0.048089
# 3             0.107592              0.411500  0.664277 -0.979104  -0.461180
# 4            -0.466193             -0.379133  0.558274  1.288643  -0.579207
#
#     alcohol
# 0 -0.960246
# 1 -0.584777
# 2 -0.584777
# 3 -0.584777
# 4 -0.960246
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_0, *['index'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_1, *['fixed acidity'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_2, *['volatile acidity'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_3, *['citric acid'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_4, *['index'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_5, *['fixed acidity'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_6, *['volatile acidity'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_7, *['citric acid'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * 6 * figscale, 6 * figscale))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(_df_8, *[[['index', 'fixed acidity'], ['fixed acidity', 'volatile acidity'], ['volatile acidity', 'citric acid'], ['citric acid', 'residual sugar']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_9, *['index', 'fixed acidity', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_10, *['index', 'volatile acidity', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_11, *['index', 'citric acid', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_12, *['index', 'residual sugar', None], **{})
# chart

# %%
y=df['quality']
y.head()

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)


x_train.shape,x_test.shape

x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.33, random_state=42)


x_train.shape, x_val.shape
# Out:
# ((717, 11), (354, 11))

# %%
layer=[
    tf.keras.layers.Input(shape=(11,),name='inputLayer'),
    tf.keras.layers.Dense(64,activation="relu", name="hiddenLayer1"),
    tf.keras.layers.Dense(8,activation="relu", name="hiddenLayer2"),
    tf.keras.layers.Dense(2,activation="sigmoid", name="outputLayer"),
    ]

# %%
model_clf = tf.keras.models.Sequential(layer)

# %%
model_clf.summary()
# Out:
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  hiddenLayer1 (Dense)        (None, 64)                768
#
#  hiddenLayer2 (Dense)        (None, 8)                 520
#
#  outputLayer (Dense)         (None, 2)                 18
#
# =================================================================
# Total params: 1306 (5.10 KB)
# Trainable params: 1306 (5.10 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
LOSS_FUNCTION = "binary_crossentropy"#function(‘binary_crossentropy’),
OPTIMIZER = "SGD" # or use with custom learning rate=> tf.keras.optimizers.SGD(0.02)
METRICS = ["accuracy"]

model_clf.compile(loss=LOSS_FUNCTION,
              optimizer=OPTIMIZER,
              metrics=METRICS)

# %%
his=model_clf.fit(x_train, y_train,epochs=50,batch_size=5,validation_data=(x_val,y_val))
# Out:
# Epoch 1/50
# 144/144 [==============================] - 2s 5ms/step - loss: 0.7182 - accuracy: 0.5523 - val_loss: 0.6794 - val_accuracy: 0.5847
# Epoch 2/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.6587 - accuracy: 0.6220 - val_loss: 0.6297 - val_accuracy: 0.6667
# Epoch 3/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.6065 - accuracy: 0.6736 - val_loss: 0.5779 - val_accuracy: 0.7260
# Epoch 4/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.5653 - accuracy: 0.7197 - val_loss: 0.5385 - val_accuracy: 0.7458
# Epoch 5/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.5411 - accuracy: 0.7280 - val_loss: 0.5145 - val_accuracy: 0.7599
# Epoch 6/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.5264 - accuracy: 0.7336 - val_loss: 0.5046 - val_accuracy: 0.7768
# Epoch 7/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.5183 - accuracy: 0.7476 - val_loss: 0.4979 - val_accuracy: 0.7571
# Epoch 8/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.5129 - accuracy: 0.7462 - val_loss: 0.4933 - val_accuracy: 0.7571
# Epoch 9/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.5083 - accuracy: 0.7448 - val_loss: 0.4901 - val_accuracy: 0.7712
# Epoch 10/50
# 144/144 [==============================] - 1s 6ms/step - loss: 0.5051 - accuracy: 0.7420 - val_loss: 0.4892 - val_accuracy: 0.7542
# Epoch 11/50
# 144/144 [==============================] - 1s 6ms/step - loss: 0.4991 - accuracy: 0.7545 - val_loss: 0.4906 - val_accuracy: 0.7684
# Epoch 12/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4979 - accuracy: 0.7517 - val_loss: 0.4842 - val_accuracy: 0.7768
# Epoch 13/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4954 - accuracy: 0.7573 - val_loss: 0.4853 - val_accuracy: 0.7684
# Epoch 14/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4927 - accuracy: 0.7531 - val_loss: 0.4869 - val_accuracy: 0.7684
# Epoch 15/50
# 144/144 [==============================] - 1s 6ms/step - loss: 0.4909 - accuracy: 0.7531 - val_loss: 0.4882 - val_accuracy: 0.7684
# Epoch 16/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4877 - accuracy: 0.7643 - val_loss: 0.4852 - val_accuracy: 0.7712
# Epoch 17/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4826 - accuracy: 0.7587 - val_loss: 0.4927 - val_accuracy: 0.7684
# Epoch 18/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4858 - accuracy: 0.7671 - val_loss: 0.4844 - val_accuracy: 0.7655
# Epoch 19/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4811 - accuracy: 0.7657 - val_loss: 0.4860 - val_accuracy: 0.7655
# Epoch 20/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4787 - accuracy: 0.7601 - val_loss: 0.4794 - val_accuracy: 0.7740
# Epoch 21/50
# 144/144 [==============================] - 1s 6ms/step - loss: 0.4781 - accuracy: 0.7685 - val_loss: 0.4855 - val_accuracy: 0.7655
# Epoch 22/50
# 144/144 [==============================] - 1s 5ms/step - loss: 0.4751 - accuracy: 0.7643 - val_loss: 0.4873 - val_accuracy: 0.7712
# Epoch 23/50
# 144/144 [==============================] - 1s 6ms/step - loss: 0.4726 - accuracy: 0.7671 - val_loss: 0.4856 - val_accuracy: 0.7684
# Epoch 24/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.4712 - accuracy: 0.7685 - val_loss: 0.4775 - val_accuracy: 0.7712
# Epoch 25/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4711 - accuracy: 0.7671 - val_loss: 0.4775 - val_accuracy: 0.7655
# Epoch 26/50
# 144/144 [==============================] - 1s 6ms/step - loss: 0.4696 - accuracy: 0.7657 - val_loss: 0.4827 - val_accuracy: 0.7740
# Epoch 27/50
# 144/144 [==============================] - 1s 6ms/step - loss: 0.4639 - accuracy: 0.7685 - val_loss: 0.4808 - val_accuracy: 0.7712
# Epoch 28/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.4638 - accuracy: 0.7699 - val_loss: 0.4752 - val_accuracy: 0.7684
# Epoch 29/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4630 - accuracy: 0.7782 - val_loss: 0.4786 - val_accuracy: 0.7655
# Epoch 30/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4607 - accuracy: 0.7838 - val_loss: 0.4790 - val_accuracy: 0.7627
# Epoch 31/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4612 - accuracy: 0.7755 - val_loss: 0.4804 - val_accuracy: 0.7655
# Epoch 32/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4575 - accuracy: 0.7866 - val_loss: 0.4846 - val_accuracy: 0.7740
# Epoch 33/50
# 144/144 [==============================] - 1s 5ms/step - loss: 0.4586 - accuracy: 0.7685 - val_loss: 0.4971 - val_accuracy: 0.7684
# Epoch 34/50
# 144/144 [==============================] - 1s 6ms/step - loss: 0.4558 - accuracy: 0.7741 - val_loss: 0.4829 - val_accuracy: 0.7712
# Epoch 35/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.4540 - accuracy: 0.7755 - val_loss: 0.4808 - val_accuracy: 0.7684
# Epoch 36/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4531 - accuracy: 0.7838 - val_loss: 0.4736 - val_accuracy: 0.7768
# Epoch 37/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4539 - accuracy: 0.7741 - val_loss: 0.4849 - val_accuracy: 0.7853
# Epoch 38/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4477 - accuracy: 0.7810 - val_loss: 0.4771 - val_accuracy: 0.7712
# Epoch 39/50
# 144/144 [==============================] - 1s 6ms/step - loss: 0.4459 - accuracy: 0.7908 - val_loss: 0.4725 - val_accuracy: 0.7740
# Epoch 40/50
# 144/144 [==============================] - 2s 11ms/step - loss: 0.4473 - accuracy: 0.7810 - val_loss: 0.4694 - val_accuracy: 0.7797
# Epoch 41/50
# 144/144 [==============================] - 2s 12ms/step - loss: 0.4437 - accuracy: 0.7824 - val_loss: 0.4804 - val_accuracy: 0.7684
# Epoch 42/50
# 144/144 [==============================] - 1s 9ms/step - loss: 0.4421 - accuracy: 0.7852 - val_loss: 0.4760 - val_accuracy: 0.7768
# Epoch 43/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4403 - accuracy: 0.7866 - val_loss: 0.4831 - val_accuracy: 0.7712
# Epoch 44/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4356 - accuracy: 0.7894 - val_loss: 0.4729 - val_accuracy: 0.7938
# Epoch 45/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4374 - accuracy: 0.7852 - val_loss: 0.4770 - val_accuracy: 0.7825
# Epoch 46/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4374 - accuracy: 0.7950 - val_loss: 0.4775 - val_accuracy: 0.7797
# Epoch 47/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4321 - accuracy: 0.7894 - val_loss: 0.4787 - val_accuracy: 0.7684
# Epoch 48/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4342 - accuracy: 0.7950 - val_loss: 0.4786 - val_accuracy: 0.7768
# Epoch 49/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4282 - accuracy: 0.7852 - val_loss: 0.4729 - val_accuracy: 0.7825
# Epoch 50/50
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4278 - accuracy: 0.7922 - val_loss: 0.4847 - val_accuracy: 0.7910

# %%
pd.DataFrame(his.history).plot()
# Out:
# <Axes: >
