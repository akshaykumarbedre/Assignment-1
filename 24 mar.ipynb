# %%
1.
import pandas as pd
import seaborn as sns
df=pd.read_csv("winequality-red.csv")
df.corr()
sns.heatmap(df.corr() ,annot=True)

#key feature feature 
##quality of wine decrease when volatile ,acidity,desnsity increase
#alcohal, sulphates increase , the wine quality increase

#alcohal, sulphates,acidity,desnsity  are important feature
# Out:
# <AxesSubplot: >

# %%
2.
we handle missing value , fill mean value if no outlier or filling medain value 
or droping the whole row 
imputation techniques:
adv: this help in data cleaning
    lossless methos 
div: we are filling mean, median which decrease performance

# %%
3.
facter: *test_preparation_course is done , then student get more marks
        *standead lunch is done , then student get more marks
factors using statistical techniques: *all the studnet were performing well . more 75% stdudnet performing get more then 57% mark

# %%
4.
import pandas as pd
import seaborn as sns
df=pd.read_csv("stud.csv")

data cleaning:
    removing dulicate value 
    fill none value 
    idernifty unque value 
converting catagrical feature to numaric 
analysis of states
corr relation bw feature
giveing conclustion
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
5.
import pandas as pd
import seaborn as sns
df=pd.read_csv("winequality-red.csv")
df.corr()
sns.heatmap(df.corr() ,annot=True)
# Out:
# <AxesSubplot: >

# %%
for i in df.columns:
    sns.displot(df[i])

# %%
citric acid,free sulfur dioxide,total sulfur dioxide,sulphates are non -normality 
what transformations could be applied to these features to improve normality:Square Root Transformation,Logarithmic Transformation.

# %%
6.
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler


wine_data =pd.read_csv("winequality-red.csv")
X = wine_data.drop(columns =['quality'])

pca = PCA(n_components=len(X.columns))
pca.fit(X)

# Calculate the cumulative sum of explained variances
explained_variance_ratio_cumulative = np.cumsum(pca.explained_variance_ratio_)

# Find the index of the first element that exceeds or equals 0.9 (90%)
num_components_for_90_variance = np.argmax(explained_variance_ratio_cumulative >= 0.9) + 1

# Reduce the data to the desired number of principal components
pca = PCA(n_components=num_components_for_90_variance)
X_reduced = pca.fit_transform(X_scaled)
print(X_reduced)
# Out:
# [[-1.61952988]
#  [-0.79916993]
#  [-0.74847909]
#  ...
#  [-1.45612897]
#  [-2.27051793]
#  [-0.42697475]]
