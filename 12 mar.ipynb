# %%
1.
mean=50
std=5
confi=0.95
import scipy.stats as st
st.norm.interval(alpha=confi,loc=mean,scale=std)
# Out:
# /tmp/ipykernel_70/3409227835.py:6: DeprecationWarning: Use of keyword argument `alpha` for method `interval` is deprecated. Use first positional argument or keyword argument `confidence` instead.
#   st.norm.interval(alpha=confi,loc=mean,scale=std)
# (40.200180077299734, 59.799819922700266)

# %%
# if the value in bw interval , we accept the null hypothisis
# else we will not reject alternative hypothis

# %%
2
import scipy.stats as stat
import numpy as np
data=[2,2,2,1,1,2]
s=0.95
n=len(data)-1
print(stat.chisquare(data)[0])
print(stat.chi2.ppf(s,n))
if(stat.chisquare(data)[0]<stat.chi2.ppf(s,n)):
    print("we accepth null hypothisi")
else:
    print("we rejest null hypothisi")
# Out:
# 0.8
# 11.070497693516351
# we accepth null hypothisi

# %%
3.
d1=[20,10,15]
d2=[15,25,20]
def per(d1):
    li=[]
    s=sum(d1)
    for i in d1:
        li.append(i/s)
    return li
d1=per(d1)
d2=per(d2)
print(stat.chisquare(d1,d2))
# In your case, the test statistic is 0.2419753086419753 and the p-value is 0.8860448983512579 1.
# The p-value is greater than 0.05 which means that we cannot reject the null hypothesis at a significance level of 5%
# Out:
# Power_divergenceResult(statistic=0.2419753086419753, pvalue=0.8860448983512579)

# %%
4
 9.5% and 14.5%.

# %%
5.
53.44 to 94.56

# %%
6.
import numpy as np 
x=np.linspace(0,chi2.ppf(0.99, df),100)
print(x)
plt.plot(x,stat.chi2.pdf(x,10))
plt.fill_between(x[x > 15], chi2.pdf(x[x > 15], 10), color='red')
plt.xlabel('x')
plt.ylabel('p(x)')
plt.title('Chi-Square Distribution with 10 Degrees of Freedom')
plt.show()
# Out:
# [ 0.          0.23443688  0.46887376  0.70331064  0.93774752  1.1721844
#   1.40662128  1.64105816  1.87549504  2.10993192  2.3443688   2.57880568
#   2.81324256  3.04767945  3.28211633  3.51655321  3.75099009  3.98542697
#   4.21986385  4.45430073  4.68873761  4.92317449  5.15761137  5.39204825
#   5.62648513  5.86092201  6.09535889  6.32979577  6.56423265  6.79866953
#   7.03310641  7.26754329  7.50198017  7.73641705  7.97085393  8.20529081
#   8.43972769  8.67416457  8.90860145  9.14303834  9.37747522  9.6119121
#   9.84634898 10.08078586 10.31522274 10.54965962 10.7840965  11.01853338
#  11.25297026 11.48740714 11.72184402 11.9562809  12.19071778 12.42515466
#  12.65959154 12.89402842 13.1284653  13.36290218 13.59733906 13.83177594
#  14.06621282 14.3006497  14.53508658 14.76952346 15.00396035 15.23839723
#  15.47283411 15.70727099 15.94170787 16.17614475 16.41058163 16.64501851
#  16.87945539 17.11389227 17.34832915 17.58276603 17.81720291 18.05163979
# ...

# %%
7.
import scipy.stats as stat
import numpy as np
edata=[50,50]
rdata=[52,48]
s=0.99
n=len(data)-1
print(stat.chisquare(edata,rdata))
print(stat.chi2.ppf(s,n))
if(stat.chisquare(edata,rdata)[0]<stat.chi2.ppf(s,n)):
    print("we accepth null hypothisi")
else:
    print("we rejest null hypothisi")
# Out:
# Power_divergenceResult(statistic=0.16025641025641024, pvalue=0.6889205558044605)
# 15.08627246938899
# we accepth null hypothisi

# %%
8.
import scipy.stats as stat
import numpy as np
edata=[50,50]
rdata=[55,45]
s=0.95
n=len(data)-1
print(stat.chisquare(edata,rdata))
print(stat.chi2.ppf(s,n))
if(stat.chisquare(edata,rdata)[0]<stat.chi2.ppf(s,n)):
    print("we accepth null hypothisi")
else:
    print("we rejest null hypothisi")
# Out:
# Power_divergenceResult(statistic=1.0101010101010102, pvalue=0.3148786413364169)
# 11.070497693516351
# we accepth null hypothisi

# %%
9.
import scipy.stats as stat
import numpy as np
edata=[30,170]
rdata=[60,140]
s=0.95
n=len(data)-1
print(stat.chisquare(edata,rdata))
print(stat.chi2.ppf(s,n))
if(stat.chisquare(edata,rdata)[0]<stat.chi2.ppf(s,n)):
    print("we accepth null hypothisi,a significant association between smoking status and lung cancer diagnosis.")
else:
    print("a significant is no association between smoking status and lung cancer diagnosis")
# Out:
# Power_divergenceResult(statistic=21.42857142857143, pvalue=3.672575114265626e-06)
# 11.070497693516351
# we rejest null hypothisi

# %%
10.
import scipy.stats as stat
import numpy as np
edata=[200,150,150]
rdata=[225,175,100]
s=0.99
n=len(data)-1
print(stat.chisquare(edata,rdata))
print(stat.chi2.ppf(s,n))
if(stat.chisquare(edata,rdata)[0]<stat.chi2.ppf(s,n)):
    print("there is a significant association between chocolate preference and country of origin.")
else:
    print("a significant is no association between smoking status and lung cancer diagnosis")
# Out:
# Power_divergenceResult(statistic=31.349206349206348, pvalue=1.5581394922806692e-07)
# 15.08627246938899
# a significant is no association between smoking status and lung cancer diagnosis

# %%
11.
The test statistic t = (x̄ - μ) / (s / √n) = (72 - 70) / (10 / √30) = 1.7321.
The degrees of freedom are df = n - 1 = 291.
Using a t-distribution table with df = 29 and α/2 = 0.025, we find that the critical values are ±2.0451. Since t = 1.732 < 2.045, we fail to reject the null hypothesis at α = 0.05 level of significance1. Therefore, there is not enough evidence to conclude that the population mean is significantly different from 701.
# Out:
# 11.0
